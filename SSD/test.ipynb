# %%
# %load_ext autoreload

# %%
# %autoreload 
import logging
from ssd.config.defaults import cfg
from ssd.utils.logger import setup_logger
from test.py import evaluation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-cf50815c473e> in <module>
#       3 from ssd.config.defaults import cfg
#       4 from ssd.utils.logger import setup_logger
# ----> 5 from test.py import evaluation
#
# ModuleNotFoundError: No module named 'test.py'

# %%
config_file = "configs/train_tdt4265.yaml"
ckpt = None # The path to the checkpoint for test, default is the latest checkpoint
cfg.merge_from_file(config_file)
cfg.freeze()

logger = setup_logger("SSD", cfg.OUTPUT_DIR)
logger.info("Loaded configuration file {}".format(config_file))
with open(config_file, "r") as cf:
    config_str = "\n" + cf.read()
    logger.info(config_str)
logger.info("Running with config:\n{}".format(cfg))
# Out:
# 2020-04-04 17:01:46,275 SSD INFO: Loaded configuration file configs/train_tdt4265.yaml
# 2020-04-04 17:01:46,275 SSD INFO: Loaded configuration file configs/train_tdt4265.yaml
# 2020-04-04 17:01:46,278 SSD INFO:
# MODEL:
#     NUM_CLASSES: 5
#     BACKBONE:
#         NAME: 'basic'
#         PRETRAINED: True
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: (300, 300)
# DATASETS:
#     TRAIN: ("tdt4265_train",)
#     TEST: ("tdt4265_val", )
# SOLVER:
#     MAX_ITER: 120000
#     LR_STEPS: [80000, 100000]
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 1e-3
# OUTPUT_DIR: 'outputs/basic'
# DATASET_DIR: "datasets"
# 2020-04-04 17:01:46,278 SSD INFO:
# MODEL:
#     NUM_CLASSES: 5
#     BACKBONE:
#         NAME: 'basic'
#         PRETRAINED: True
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: (300, 300)
# DATASETS:
#     TRAIN: ("tdt4265_train",)
#     TEST: ("tdt4265_val", )
# SOLVER:
#     MAX_ITER: 120000
#     LR_STEPS: [80000, 100000]
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 1e-3
# OUTPUT_DIR: 'outputs/basic'
# DATASET_DIR: "datasets"
# 2020-04-04 17:01:46,280 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('tdt4265_val',)
#   TRAIN: ('tdt4265_train',)
# DATASET_DIR: datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: (300, 300)
#   PIXEL_MEAN: [123, 117, 104]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: basic
#     OUT_CHANNELS: (128, 256, 128, 128, 64, 64)
#     PRETRAINED: True
#   BOX_HEAD:
#     NAME: SSDBoxHead
#     PREDICTOR: SSDBoxPredictor
#   CENTER_VARIANCE: 0.1
#   META_ARCHITECTURE: SSDDetector
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 5
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [60, 111, 162, 213, 264, 315]
#     MIN_SIZES: [30, 60, 111, 162, 213, 264]
#     STRIDES: [8, 16, 32, 64, 100, 300]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.001
#   LR_STEPS: [80000, 100000]
#   MAX_ITER: 120000
#   MOMENTUM: 0.9
#   WARMUP_FACTOR: 0.3333333333333333
#   WARMUP_ITERS: 500
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2020-04-04 17:01:46,280 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('tdt4265_val',)
#   TRAIN: ('tdt4265_train',)
# DATASET_DIR: datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: (300, 300)
#   PIXEL_MEAN: [123, 117, 104]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: basic
#     OUT_CHANNELS: (128, 256, 128, 128, 64, 64)
#     PRETRAINED: True
#   BOX_HEAD:
#     NAME: SSDBoxHead
#     PREDICTOR: SSDBoxPredictor
#   CENTER_VARIANCE: 0.1
#   META_ARCHITECTURE: SSDDetector
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 5
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [60, 111, 162, 213, 264, 315]
#     MIN_SIZES: [30, 60, 111, 162, 213, 264]
#     STRIDES: [8, 16, 32, 64, 100, 300]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.001
#   LR_STEPS: [80000, 100000]
#   MAX_ITER: 120000
#   MOMENTUM: 0.9
#   WARMUP_FACTOR: 0.3333333333333333
#   WARMUP_ITERS: 500
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45

# %%
evaluation(cfg, ckpt=ckpt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c7b6f2a5ff9a> in <module>
# ----> 1 evaluation(cfg, ckpt=ckpt)
#
# NameError: name 'evaluation' is not defined
